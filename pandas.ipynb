# %%
# !pip install pandas

# %%
ls

# %%
import pandas as pd

df = pd.read_csv('refined_imp_theorem_NK.csv') # read data file || .csv format

df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
df.describe()
# Out:
#              votesA        votesB          area     perimeter  pp_compactness  \
# count  40000.000000  40000.000000  40000.000000  40000.000000    40000.000000
# mean      16.900000     21.125000      9.506250     20.276475        0.282000
# std        2.616423      3.132015      1.215237      1.748274        0.031087
# min        9.000000     12.000000      6.750000     16.000000        0.144184
# 25%       15.000000     20.000000      8.250000     19.000000        0.259504
# 50%       17.000000     21.000000      9.250000     20.000000        0.278338
# 75%       18.000000     23.000000     10.250000     22.000000        0.284807
# max       23.000000     28.000000     11.750000     28.000000        0.441563
#
#                  eg      imp_flag   win_count_a   win_count_b   total_votes  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.348752      0.999950      0.476950      7.772650    309.150000
# ...

# %%
print(df.columns)
# Out:
# Index(['votesA', 'votesB', 'area', 'perimeter', 'pp_compactness', 'eg',
#        'imp_flag', 'win_count_a', 'win_count_b', 'total_votes',
#        'state_votes_a', 'state_votes_b', 'P_a', 'P_b', 'p_a', 'p_b',
#        'pOverP_a', 'pOverP_b', 'n', 'L', 'K', 'proportion_a', 'left_side',
#        'right_side', 'refined_left_side', 'refinded_right_side'],
#       dtype='object')

# %%
# read a specific column
print(df['refinded_right_side'][0:5]) # you can omit [0:5] to print all
# Out:
# 0    0.85278
# 1    0.85278
# 2    0.85278
# 3    0.85278
# 4    0.85278
# Name: refinded_right_side, dtype: float64

# %%
print(df.head(4)) # print specific number of rows
# Out:
#    votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0      16      22   9.5         21        0.256327  0.222222         1
# 1      20      18   9.5         20        0.282600  0.222222         1
# 2      17      21   9.5         26        0.167219  0.222222         1
# 3      17      21   9.5         20        0.282600  0.222222         1
#
#    win_count_a  win_count_b  total_votes  ...  pOverP_a  pOverP_b  n  L  K  \
# 0            1            5          225  ...  2.666667  0.666667  5  9  6
# 1            1            5          225  ...  2.666667  0.666667  5  9  6
# 2            1            5          225  ...  2.666667  0.666667  5  9  6
# 3            1            5          225  ...  2.666667  0.666667  5  9  6
#
#    proportion_a  left_side  right_side  refined_left_side  refinded_right_side
# 0         0.555        0.8   -0.992407                0.8              0.85278
# ...

# %%
for index, row in df.iterrows():
    print(index, row['perimeter']) # specific column

# %%
df.loc[df['win_count_a'] == 1]
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
df.sort_values(['votesA', 'win_count_a'], ascending=[0,1]) # [dscending,ascending]
# Out:
#        votesA  votesB   area  perimeter  pp_compactness        eg  imp_flag  \
# 6012       23      24  11.75         23        0.261172  0.395062         1
# 6019       23      24  11.75         23        0.261172  0.398148         1
# 6026       23      24  11.75         23        0.261172  0.398148         1
# 6033       23      24  11.75         23        0.261172  0.398148         1
# 6040       23      24  11.75         23        0.261172  0.398148         1
# ...       ...     ...    ...        ...             ...       ...       ...
# 39993      11      20   7.75         16        0.343438  0.308642         1
# 30013      11      22   8.25         17        0.347682  0.191358         1
# 30026      10      19   7.25         18        0.271358  0.299383         1
# 30016      10      19   7.25         17        0.304221  0.191358         1
# 30007       9      24   8.25         19        0.278338  0.299383         1
#
# ...

# %%
df['total_pop'] = df['votesA'] + df['votesB'] # add new col called 'total'

# %%
df.head(5) # print first 5
# Out:
#    votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0      16      22   9.5         21        0.256327  0.222222         1
# 1      20      18   9.5         20        0.282600  0.222222         1
# 2      17      21   9.5         26        0.167219  0.222222         1
# 3      17      21   9.5         20        0.282600  0.222222         1
# 4      14      24   9.5         22        0.233554  0.222222         1
#
#    win_count_a  win_count_b  total_votes  ...  n  L  K  proportion_a  \
# 0            1            5          225  ...  5  9  6         0.555
# 1            1            5          225  ...  5  9  6         0.555
# 2            1            5          225  ...  5  9  6         0.555
# 3            1            5          225  ...  5  9  6         0.555
# 4            1            5          225  ...  5  9  6         0.555
#
#    left_side  right_side  refined_left_side  refinded_right_side  \
# ...

# %%
df = df.drop(columns=['total_pop']) # drop a column and resave the df
df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
df['total_population'] = df.iloc[:,0:2].sum(axis=1) # [all rows, first two columns]
#its 0-2 because pandas doesn't count first one in the operation
# axis = 1 add horizontally 
# I just wanted to show you this way but in general 
# try to include column names incase the ordering changes
df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
df_imp_winA_1 = df.loc[(df['imp_flag'] == 1) &  (df['win_count_a'] >= 1)] # use | for or operation
# extend list with &, | operations to as many columns as you need use parenthesis for groupings 
df.loc[(df['imp_flag'] == 1) &  (df['win_count_a'] >= 1)] # don't assing to var if you just want to view
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
df_imp_winA_1.describe() # save for extended analysis
# Out:
#              votesA        votesB          area     perimeter  pp_compactness  \
# count  19012.000000  19012.000000  19012.000000  19012.000000    19012.000000
# mean      15.159268     18.949663      8.527233     19.108721        0.287517
# std        2.061897      2.438673      0.551046      1.126716        0.028264
# min        9.000000     12.000000      6.750000     16.000000        0.144184
# 25%       13.000000     17.000000      8.250000     19.000000        0.278338
# 50%       15.000000     20.000000      8.250000     19.000000        0.278338
# 75%       16.000000     20.000000      9.000000     20.000000        0.310123
# max       21.000000     25.000000     10.250000     28.000000        0.441563
#
#                  eg  imp_flag   win_count_a   win_count_b   total_votes  ...  \
# count  19012.000000   19012.0  19012.000000  19012.000000  19012.000000  ...
# mean       0.296492       1.0      1.003261      8.520776    323.968757  ...
# ...

# %% [markdown]
# ## AI chat bot QA data

# %%
df2 = pd.read_csv('AI.csv')
df2
# Out:
#                                               Question  \
# 0    Who did the first work generally recognized as...
# 1    What sources was drawn on the formation of the...
# 2               Who created the Hebbian learning rule?
# 3              When the first neural network is built?
# 4             What is the first neural network called?
# ..                                                 ...
# 498            How long uniform-cost search will take?
# 499  How much space does uniform-cost search take t...
# 500  How much space does iterative deepening search...
# 501  How much space does depth-first search take to...
# 502  How much space does breadth-first search take ...
#
#                                                 Answer
# 0          Warren McCulloch and Walter Pitts (1943).\n
# 1    knowledge of the basic physiology and function...
# 2                                Donald Hebb (1949).\n
# 3                                              1950.\n
# ...

# %%
import re

#use

df2.loc[df2['Question'].str.contains('long|deeping', flags=re.I, regex=True)] # re.I ignore letter case
# Out:
#                                               Question  \
# 67   Who was motivated to consider the long-term fu...
# 486           How long breadth-first search will take?
# 489             How long depth-first search will take?
# 494     How long iterative deepening search will take?
# 498            How long uniform-cost search will take?
#
#                                                 Answer
# 67                                    Norbert Wiener\n
# 486    1+b+b^2+b^3+… +b^d (nodes until the solution)\n
# 489                      O(b^m) with m=maximum depth\n
# 494      b + (b+b^2) + .......(b+....b^d)  = O(b^d).\n
# 498  of nodes with path cost ≤ cost of optimal solu...

# %%
df2.loc[df2['Question'].str.contains('^h[a-z]*', flags=re.I, regex=True)] # ^ start with, * contains more than 1 of a-z
# Out:
#                                               Question  \
# 30   How is the performance of certainty factors in...
# 40   How is the connectionist models better suited ...
# 54   How does deep network contribute to ALPHAGO's ...
# 74              How AI is stucked to consequentialism?
# 75   How can we capture the desirability related to...
# 84       How we will say that an agent lacks autonomy?
# 90   How can we say a task environment is fully obs...
# 91   How can we say a task environment is determini...
# 94      How can we say a task environment is episodic?
# 95    How can we say a task environment is sequential?
# 98   How can we say a task environment is dynamic f...
# 99   How can we say a task environment is static fo...
# 101  How can we say a task environment is semidynamic?
# 106        How can we say a task environment is known?
# 107      How can we say a task environment is unknown?
# 118  How can a simple reflex agen escape from infin...
# ...
