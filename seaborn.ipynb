# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# show plot directly inside notebook
# autoreload changes
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv('refined_imp_theorem_NK.csv') # read data file || .csv format
df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
sns.displot(df['pp_compactness'], kde=True)

# %%
sns.jointplot(x='eg', y ='win_count_a', data=df, kind='reg')

# %%
sns.jointplot(x='pp_compactness', y ='win_count_a', data=df, kind='reg')

# %%
sns.jointplot(x='pp_compactness', y ='win_count_a', data=df, kind='kde')

# %%
sns.jointplot(x='refinded_right_side', y ='win_count_a', data=df, kind='hex')

# %%
sns.pairplot(df)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x='refinded_right_side', y ='win_count_a', data=df, kind='kde')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('poster',font_scale=1.4)
sns.jointplot(x='refinded_right_side', y ='win_count_a', data=df, kind='reg')
sns.despine(left=True, bottom=True)
# Out:
# C:\Users\Saeed\anaconda3\lib\site-packages\seaborn\axisgrid.py:1760: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
plt.figure(figsize=(14,5))
sns.set_context('paper',font_scale=1.4)
sns.barplot(x='win_count_a', y='pp_compactness', data=df, estimator=np.std)
# Out:
# <Axes: xlabel='win_count_a', ylabel='pp_compactness'>

# %%
sns.barplot(x='win_count_a', y='pp_compactness', data=df, estimator=np.var)
# Out:
# <Axes: xlabel='win_count_a', ylabel='pp_compactness'>

# %%
sns.barplot(x='win_count_a', y='pp_compactness', data=df, estimator=np.cov)
# Out:
# <Axes: xlabel='win_count_a', ylabel='pp_compactness'>

# %%
sns.boxplot(x='win_count_a', y='eg', data=df, hue='win_count_a')
plt.legend(loc=0)

# %%
sns.boxplot(x='win_count_b', y='eg', data=df, hue='win_count_b')
plt.legend(loc=4)

# %%
sns.boxplot(x='win_count_a', y='pp_compactness', data=df, hue='win_count_a')
plt.legend(loc=1)

# %%
sns.violinplot(x='win_count_a', y='pp_compactness', data=df, hue='win_count_a')
plt.legend(loc=1)

# %%
df
# Out:
#        votesA  votesB  area  perimeter  pp_compactness        eg  imp_flag  \
# 0          16      22  9.50         21        0.256327  0.222222         1
# 1          20      18  9.50         20        0.282600  0.222222         1
# 2          17      21  9.50         26        0.167219  0.222222         1
# 3          17      21  9.50         20        0.282600  0.222222         1
# 4          14      24  9.50         22        0.233554  0.222222         1
# ...       ...     ...   ...        ...             ...       ...       ...
# 39995      13      20  8.25         19        0.278338  0.308642         1
# 39996      12      20  8.00         19        0.278338  0.308642         1
# 39997      13      20  8.25         19        0.278338  0.308642         1
# 39998      16      17  8.25         19        0.278338  0.308642         1
# 39999      18      12  7.50         19        0.243546  0.308642         1
#
# ...

# %%
sns.stripplot(x='n', y='pp_compactness', data=df, jitter=True, hue='win_count_a', dodge=True)
plt.legend(loc=2)

# %%
# takes forever to run!!!!
sns.violinplot(x='win_count_a', y='K', data=df, hue='win_count_a')
sns.swarmplot(x='win_count_a', y='K', data=df, hue='win_count_a', color='white')

plt.legend(loc=1)

# %% [markdown]
# ### Palettes

# %%
plt.figure(figsize=(8,5))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='win_count_a', y='pp_compactness',data=df,hue='win_count_a', palette='afmhot')
# Out:
# <Axes: xlabel='win_count_a', ylabel='pp_compactness'>

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
# correlation function used to create heatmaps
df_mx = df.corr()
df_mx
# Out:
#                        votesA    votesB      area  perimeter  pp_compactness  \
# votesA               1.000000  0.425497  0.812411   0.672595       -0.203803
# votesB               0.425497  1.000000  0.873347   0.651479       -0.058349
# area                 0.812411  0.873347  1.000000   0.781789       -0.147293
# perimeter            0.672595  0.651479  0.781789   1.000000       -0.714285
# pp_compactness      -0.203803 -0.058349 -0.147293  -0.714285        1.000000
# eg                   0.597064  0.623469  0.723086   0.604097       -0.187329
# imp_flag            -0.002973  0.009313  0.004401  -0.000904        0.006423
# win_count_a         -0.629340 -0.657173 -0.762175  -0.630424        0.166036
# win_count_b         -0.462209 -0.482650 -0.559768  -0.441825        0.077689
# total_votes          0.037464  0.039121  0.045371   0.026105        0.012674
# state_votes_a        0.037464  0.039121  0.045371   0.026105        0.012674
# ...

# %%
plt.figure(figsize=(20,10))
sns.set_context('paper')
sns.heatmap(df_mx, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights')
flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.violinplot(x='month', y='passengers', data=flights, hue='year')
sns.swarmplot(x='month', y='passengers', data=flights, hue='year', color='white')

plt.legend(loc=1)
# Out:
# C:\Users\Saeed\anaconda3\lib\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:white'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(flights_pivot, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights_pivot, cmap='Blues', standard_scale=1)

# %% [markdown]
# ### cluster maps

# %%
sns.clustermap(df)
# Out:
# C:\Users\Saeed\anaconda3\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
df_a = sns.PairGrid(df, hue='K')

# %%
df_a.map(plt.scatter)

# %%
df_a.map_diag(plt.hist)
df_a.map_offdiag(plt.scatter)
df_a.map_upper(plt.scatter)
df_a.map_lower(sns.kde)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue="species")
iris_g.map_diag(plt.hist)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
iris_g = sns.PairGrid(iris, hue='species', 
                      x_vars=['sepal_length','sepal_width'],
                      y_vars=['petal_length','sepal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# ## Facet Grid

# %%
tips = sns.load_dataset('tips')
tips_fg = sns.FacetGrid(tips, col='time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips, col='time', hue='smoker', height=4, aspect=1.3, col_order=['Dinner','Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill','tip', edgecolor='w')

# %%
kws = dict(s=50, linewidth=0.5, edgecolor='w')
tips_fg= sns.FacetGrid(tips, col='sex', hue='smoker',height=4,aspect=1.3,hue_order=['Yes','No'], 
                      hue_kws=dict(marker=['^','v']))
tips_fg.map(plt.scatter, 'total_bill','tip',**kws)

# %%
att_df = sns.load_dataset('attention')
att_df.head()
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
att_fg = sns.FacetGrid(att_df, col='subject', col_wrap=5,height=1.5)
att_fg.map(plt.plot, 'solutions','score',marker='.')

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips,markers=['o','^'],
          scatter_kws={'s':100,'linewidth':0.5, 'edgecolor':'w'})

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips)
